# %% [markdown]
# # Notebook com o código para a seleção de 250 amostras que vamos utilizar para a detecção de phishing

# %%
import pandas as pd
import numpy as np
import google.generativeai as genai
from google.colab import userdata

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#Le o dataset de spam de emails
dataset_spam_email = pd.read_csv("/content/drive/MyDrive/Projeto Hackoon 2024/dados/emails.csv")
dataset_spam_email.head()

# %%
#Lendo o dataset com dados de SMS e Emails
with open('/content/drive/MyDrive/Projeto Hackoon 2024/dados/texts.json') as f:
    data = json.load(f)
dataset_texts = pd.DataFrame(data)
dataset_texts.head()

# %%
#Lendo o dataset com urls de site
with open('/content/drive/MyDrive/Projeto Hackoon 2024/dados/urls.json') as f:
    data = json.load(f)
dataset_urls = pd.DataFrame(data)
dataset_urls.head()

# %%
#Lendo o dataset com HTML de siteS
with open('/content/drive/MyDrive/Projeto Hackoon 2024/dados/webs.json') as f:
    data = json.load(f)
dataset_webs = pd.DataFrame(data)
dataset_webs.head()

# %%
#Selecionando 80 amostras aleatorias do dataset de spam de email, sendo 40 legitimos e 40 phishing
sample_spam_email = dataset_spam_email.groupby('spam').apply(lambda x: x.sample(25))

# Display the sample
print(sample_spam_email)

# %%
#Selecionando 80 amostras aleatorias do dataset de textos, sendo 40 legitimos e 40 phishing
sample_texts = dataset_texts.groupby('label').apply(lambda x: x.sample(60))

# Display the sample
print(sample_texts)

# %%
#Selecionando 40 amostras aleatorias do dataset de urls, sendo 20 legitimos e 20 phishing
sample_urls = dataset_urls.groupby('label').apply(lambda x: x.sample(20))

# Display the sample
print(sample_urls)

# %%
#Selecionando 40 amostras aleatorias do dataset de spam de html, sendo 20 legitimos e 20 phishing
sample_webs = dataset_webs.groupby('label').apply(lambda x: x.sample(20))

# Display the sample
print(sample_webs)

# %%
#from genericpath import sameopenfile
#renomeando a coluna de categoria que diz que é phishing ou não para "phishing"
sample_spam_email.rename(columns = {'spam': 'phishing'}, inplace = True)
sample_texts.rename(columns = {'label': 'phishing'}, inplace = True)
sample_urls.rename(columns = {'label': 'phishing'}, inplace = True)
sample_webs.rename(columns = {'label': 'phishing'}, inplace = True)

# %%
#juntando as amostras
dataset_final = pd.concat([sample_spam_email, sample_texts, sample_urls, sample_webs])
dataset_final.iloc[1]

# %%
dataset_final

# %%
#salvando o dataset final como csv
dataset_final.to_csv('/content/drive/Shareddrives/Projeto Hackoon/dataset_final_250.csv')
